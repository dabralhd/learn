# %%
import os
import json
from genson import SchemaBuilder
from sklearn.feature_extraction import DictVectorizer
from sklearn.cluster import AgglomerativeClustering
from pprint import pprint

import csv
import shutil
from pathlib import Path

# %%
def get_matching_json_paths(top_level_directory, pattern="ai_*.json"):
    """
    Recursively finds all files matching the given pattern 
    within the given top-level directory.
    
    :param top_level_directory: Path or string of the root directory to search.
    :return: A list of string paths matching the pattern.
    """
    # Convert string input to a Path object if necessary
    root_path = Path(top_level_directory)
    
    # Ensure the directory actually exists before searching
    if not root_path.exists() or not root_path.is_dir():
        print(f"Error: The directory '{top_level_directory}' does not exist or is not a directory.")
        return []

    # Find paths matching the pattern recursively
    # and convert them to standard string paths
    matching_paths = [str(file_path) for file_path in root_path.rglob(pattern)]
    
    return matching_paths

# --- Example Usage ---
# directory_to_scan = "./proj-api-volume-dump"
# results = get_matching_json_paths(directory_to_scan)
# print(f"Found {len(results)} matching configuration files.")

# %% [markdown]
# ## Rename DEV cluster ai-json files

# %%
ai_json_files = get_matching_json_paths(top_level_directory='~/Downloads/proj-api-volume-dump')

pprint(f'ai json file count: {len(ai_json_files)}')
pprint(ai_json_files)
# Out:
# 'ai json file count: 1886'
# ['proj-api-volume-dump\\proj-api-volume-dump\\zzfzy60gza1rk3ph63359yqk10\\workspace\\projects\\project_name_660660_shared\\ai_project_name_660660_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\zws54kghj2jmbz6dqde24xfk10\\workspace\\projects\\project_name_628255_shared\\ai_project_name_628255_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\zd99b9vvbkvjevpynf1c4w9k10\\workspace\\projects\\project_name_82196\\ai_project_name_82196.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\zcx9qer6eb4gpe8kqfxethqk10\\workspace\\projects\\Image_Payload\\ai_Image_Payload.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\zcx9qer6eb4gpe8kqfxethqk10\\workspace\\projects\\JsonTest\\ai_JsonTest.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\zcx9qer6eb4gpe8kqfxethqk10\\workspace\\projects\\svg\\ai_svg.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\zcx9qer6eb4gpe8kqfxethqk10\\workspace\\projects\\svg_script\\ai_svg_script.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\zcx9qer6eb4gpe8kqfxethqk10\\workspace\\projects\\TestJS_Script\\ai_TestJS_Script.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\zc8raewh3bnzen8pvk8rxdfk10\\workspace\\projects\\DatasetProject_780152\\ai_DatasetProject_780152.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\z65bm12e08dqmhyrm5hkxwfk10\\workspace\\projects\\project_name_390366\\ai_project_name_390366.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\yysyzjq4p4jvq4gjjp60ydfk10\\workspace\\projects\\Dataset_Project_611809\\ai_Dataset_Project_611809.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\yed3n9097yk1m707ajhyf8ak10\\workspace\\projects\\project_name_347199\\ai_project_name_347199.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\yd83zzet5yrr5fptbyjgyffk10\\workspace\\projects\\project_name_657659-shared\\ai_project_name_657659-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\y52cs663w1gecz5enz7gdyqk10\\workspace\\projects\\project_name_925277_shared\\ai_project_name_925277_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\y4p0yzxwgzt0ep9bt0sfayqk10\\workspace\\projects\\project_name_702176_shared\\ai_project_name_702176_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\y3j6crcdhnn0fbwyc92xzdfk10\\workspace\\projects\\TennisST\\ai_TennisST.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\y3j6crcdhnn0fbwyc92xzdfk10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\xymk3x1dpkr28pd1n6gzayqk10\\workspace\\projects\\project_name_720994_shared\\ai_project_name_720994_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\xscxsh08yq5tyqvbqmkddyqk10\\workspace\\projects\\project_name_238698_shared\\ai_project_name_238698_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\xsbzs0rzffjhtyyhf96qkbrk10\\workspace\\projects\\project_name_523222_shared\\ai_project_name_523222_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\xrf075d0shkvr08za544bwqk10\\workspace\\projects\\project_name_843911_shared\\ai_project_name_843911_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\xpktnncr5vv5h7jyyqgv8xrk10\\workspace\\projects\\project_name_974625_shared\\ai_project_name_974625_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\xbwae7wwnn52vb9yy3sjk3hk10\\workspace\\projects\\project_name_255564_shared\\ai_project_name_255564_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\x2yacgtda5d4cwsgnvrz1gfk10\\workspace\\projects\\Dataset_Project_73647\\ai_Dataset_Project_73647.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\x20wpn5jn0hp6gc722dwxffk10\\workspace\\projects\\project_name_765720\\ai_project_name_765720.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ww0xe0dds5phx4m3rdnhcwqk10\\workspace\\projects\\project_name_802517_shared\\ai_project_name_802517_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\wexek2s52e568ztcmthjdkck10\\workspace\\projects\\Gesture\\ai_Gesture.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\wexek2s52e568ztcmthjdkck10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\wav5ndzp5e89pe210zbqnqzj10\\workspace\\projects\\sharedTest\\ai_sharedTest.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\wav5ndzp5e89pe210zbqnqzj10\\workspace\\projects\\test-project-1\\ai_test-project-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\wav5ndzp5e89pe210zbqnqzj10\\workspace\\projects\\test-project-1-hd\\ai_test-project-1-hd.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\wav5ndzp5e89pe210zbqnqzj10\\workspace\\projects\\test-shared1\\ai_test-shared1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\wav5ndzp5e89pe210zbqnqzj10\\workspace\\projects\\testDrill\\ai_testDrill.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\wav5ndzp5e89pe210zbqnqzj10\\workspace\\projects\\testMember\\ai_testMember.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\w6dvvtdr027h8r01f8xgmfsk10\\workspace\\projects\\project_name_530547_shared\\ai_project_name_530547_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\w636hrt40909a3c3rrp65gfk10\\workspace\\projects\\project_name_98880-shared\\ai_project_name_98880-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\vp760yzmtzntdcx54d8hkbrk10\\workspace\\projects\\project_name_287585_shared\\ai_project_name_287585_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\vnfvhntq7fgj5s25tskn2gfk10\\workspace\\projects\\tttt\\ai_tttt.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\v1bp3d04cs8abcyrtr7nkbrk10\\workspace\\projects\\project_name_83481_shared\\ai_project_name_83481_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\twnjqbeksw7k9cwj6dj5bwqk10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\tnabe7av8wpv220xhn7ksdfk10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\tkgknjr3xdxk6w9q4eb9yffk10\\workspace\\projects\\project_name_583527shared\\ai_project_name_583527shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\tgqvmnz4amcfea3nf46fxffk10\\workspace\\projects\\project_name_336069\\ai_project_name_336069.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\tgcva2q731sj75xgeq5jyffk10\\workspace\\projects\\project_name_250813-shared\\ai_project_name_250813-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\terghh5wbk164hpje8rdxffk10\\workspace\\projects\\project_name_691370\\ai_project_name_691370.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\tbt37e87fqvv241kqg0sk3hk10\\workspace\\projects\\project_name_38687_shared\\ai_project_name_38687_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\tag0c90tem545en8wbhqk3hk10\\workspace\\projects\\project_name_577245_shared\\ai_project_name_577245_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\t3m2tjjsemav365yncm81efk10\\workspace\\projects\\nicoClone\\ai_nicoClone.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\t3m2tjjsemav365yncm81efk10\\workspace\\projects\\Reco\\ai_Reco.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\t3m2tjjsemav365yncm81efk10\\workspace\\projects\\tennisLOL\\ai_tennisLOL.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\t1zypqpwfpjc095d7443kbrk10\\workspace\\projects\\project_name_659653_shared\\ai_project_name_659653_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\t0at9e8s509sab9f0fnh5gfk10\\workspace\\projects\\project_name_423878-shared\\ai_project_name_423878-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sr7wthnjeqf954js983nayqk10\\workspace\\projects\\project_name_971177_shared\\ai_project_name_971177_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\clone-TBC-group-1\\ai_clone-TBC-group-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\gproject1\\ai_gproject1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\group-user_project_1-clone\\ai_group-user_project_1-clone.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\group-user_project_2-clone\\ai_group-user_project_2-clone.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\TBC_gproject1_clone\\ai_TBC_gproject1_clone.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\test-project-110\\ai_test-project-110.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\test-project-111\\ai_test-project-111.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\test-project-112\\ai_test-project-112.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\test-project-114\\ai_test-project-114.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\sp4n95r2rc4he7b4rpzdpqtj10\\workspace\\projects\\test-project-210\\ai_test-project-210.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\smbrxxh1vgafjbz19nk9bw9k10\\workspace\\projects\\project_name_761267\\ai_project_name_761267.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\s6kj0kbr8s90np3hyk685gfk10\\workspace\\projects\\project_name_425375-shared\\ai_project_name_425375-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\rza4art5pttpsb9s8e2vdyqk10\\workspace\\projects\\project_name_720314_shared\\ai_project_name_720314_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ryvjd288pwsp6qneyfte2gfk10\\workspace\\projects\\err\\ai_err.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\rwztwj20818qr3p656wx2kak10\\workspace\\projects\\tennis\\ai_tennis.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\rwztwj20818qr3p656wx2kak10\\workspace\\projects\\tennisBug\\ai_tennisBug.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\rwztwj20818qr3p656wx2kak10\\workspace\\projects\\testDataset\\ai_testDataset.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\rwztwj20818qr3p656wx2kak10\\workspace\\projects\\testM\\ai_testM.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\rvq2g4wh76549mgtw7mrrdfk10\\workspace\\projects\\project_name_405074\\ai_project_name_405074.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\rhcs6q6fw3wyrv25gcahrs9k10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ree1fz3yf5pjwcd5fpzemfsk10\\workspace\\projects\\project_name_460752_shared\\ai_project_name_460752_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r7ftr7tkb800nesyn5zpcyqk10\\workspace\\projects\\project_name_906025\\ai_project_name_906025.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r451sv2zetznhv77qwytk71k10\\workspace\\projects\\group-project-101\\ai_group-project-101.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r451sv2zetznhv77qwytk71k10\\workspace\\projects\\test-project-2\\ai_test-project-2.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r451sv2zetznhv77qwytk71k10\\workspace\\projects\\test-project-2_TC_4_P\\ai_test-project-2_TC_4_P.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r451sv2zetznhv77qwytk71k10\\workspace\\projects\\test-project-group-from-scratch-2_TC_3_p\\ai_test-project-group-from-scratch-2_TC_3_p.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r451sv2zetznhv77qwytk71k10\\workspace\\projects\\test-project-group-from-scratch_TC_3_p\\ai_test-project-group-from-scratch_TC_3_p.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r451sv2zetznhv77qwytk71k10\\workspace\\projects\\test_project_tc-804_clone\\ai_test_project_tc-804_clone.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r2ms59rfkpwp2cat705esdfk10\\workspace\\projects\\project_name_913282\\ai_project_name_913282.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\r1wg7fefcs53g6fa095tcpck10\\workspace\\projects\\AppleWatch\\ai_AppleWatch.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\qwj9q8d17fj96nw24h7qns9k10\\workspace\\projects\\project_name_783049\\ai_project_name_783049.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\qsvmzmy32e4ncday907dayqk10\\workspace\\projects\\project_name_816287_shared\\ai_project_name_816287_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\qm5zy3970dhtmehsx8vpkfsk10\\workspace\\projects\\project_name_445013\\ai_project_name_445013.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\qj0rv9zerffz6gw61m7z8xrk10\\workspace\\projects\\project_name_34328_shared\\ai_project_name_34328_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\qb3qcxcg7ewya7b00kqwxdfk10\\workspace\\projects\\Dataset_Project_984856\\ai_Dataset_Project_984856.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\q8tqgg0v1pwsqn2f844ywffk10\\workspace\\projects\\project_name_722148\\ai_project_name_722148.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\pyrtesqc1wd16xt85z45ffgk10\\workspace\\projects\\my_asset_tracking_clone_test\\ai_my_asset_tracking_clone_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\px18hehstk7gc04t2d3hqgfk10\\workspace\\projects\\project_name_846145_shared\\ai_project_name_846145_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\pt1xy1qxdw848p2a8t208xrk10\\workspace\\projects\\project_name_613278\\ai_project_name_613278.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\pskxwhmydkw1m0t8nxk2nqtj10\\workspace\\projects\\20250904-test-1\\ai_20250904-test-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\pskxwhmydkw1m0t8nxk2nqtj10\\workspace\\projects\\auto-expert-test\\ai_auto-expert-test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\pskxwhmydkw1m0t8nxk2nqtj10\\workspace\\projects\\my-sat-project\\ai_my-sat-project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\pr43rmenh6mm69gzvy0exdfk10\\workspace\\projects\\DatasetProject_865188\\ai_DatasetProject_865188.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\pkv17wtw1dwpkw3keex4mdfk10\\workspace\\projects\\project_name_645348\\ai_project_name_645348.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\phea0jb5eepxr1bh1ahwjsvj10\\workspace\\projects\\sat-iot-system-1\\ai_sat-iot-system-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\pb3y12yc7jachch3k0w2e3hk10\\workspace\\projects\\project_name_19608_shared\\ai_project_name_19608_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\nenw3kka7qayve58gfbhk3hk10\\workspace\\projects\\project_name_727411_shared\\ai_project_name_727411_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\mw909mkp73js5hy7z3d15gfk10\\workspace\\projects\\project_name_165853\\ai_project_name_165853.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\mq1zcse1zpzjff9bxpmwsg2k10\\workspace\\projects\\smart_asset_tracking_clone-1\\ai_smart_asset_tracking_clone-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\mq1zcse1zpzjff9bxpmwsg2k10\\workspace\\projects\\Testing-grp-2-hd-project\\ai_Testing-grp-2-hd-project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\mhqpxmkhwnawkj9p60gmk3hk10\\workspace\\projects\\project_name_179827_shared\\ai_project_name_179827_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\m5wvsm00hbw5ap86qfyhxffk10\\workspace\\projects\\project_name_713720\\ai_project_name_713720.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\m13nn0nxtzvy828wy7s4zffk10\\workspace\\projects\\project_name_387276-shared\\ai_project_name_387276-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\kha5q6x01e0heen6tzf7e3hk10\\workspace\\projects\\project_name_580565_shared\\ai_project_name_580565_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\kgm2z7y3wmhcb8257xbb5gfk10\\workspace\\projects\\project_name_565377-shared\\ai_project_name_565377-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\kg6cqd9gn6zfkmj7q88j9yqk10\\workspace\\projects\\project_name_981700_shared\\ai_project_name_981700_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\k8k35jht2sw4pgqsw6d4e3hk10\\workspace\\projects\\project_name_539240_shared\\ai_project_name_539240_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\jvqage4rrfmpg1q9mfcf9yqk10\\workspace\\projects\\project_name_409737_shared\\ai_project_name_409737_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\jrqgw59kgrx2rg7843c37msk10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\jkb8n3ejsjtdmfps29qx2gfk10\\workspace\\projects\\sdadasdasd\\ai_sdadasdasd.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\jh3h9phe90m6f133fsz8e3hk10\\workspace\\projects\\project_name_259042_shared\\ai_project_name_259042_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\hv9qvbhz6fq2q9a01ce2zffk10\\workspace\\projects\\project_name_648357-shared\\ai_project_name_648357-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\htgh1fzprqrjfqnqmsx5bwqk10\\workspace\\projects\\project_name_886526_shared\\ai_project_name_886526_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\hrj8a316n7ee34t232mgxffk10\\workspace\\projects\\project_name_524696\\ai_project_name_524696.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\hr33xr14xfsgkwnrz8k79yqk10\\workspace\\projects\\project_name_495851_shared\\ai_project_name_495851_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\hnz7kjk3ps8e15d0b7njawqk10\\workspace\\projects\\project_name_363615_shared\\ai_project_name_363615_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\h8kcc5k95v0g1ejzh7frxffk10\\workspace\\projects\\project_name_705358\\ai_project_name_705358.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\h8f4feb84vgmx9e5q1g8dyqk10\\workspace\\projects\\project_name_438886_shared\\ai_project_name_438886_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\h4jxrgtyqpz08xpk1v9g5bkk10\\workspace\\projects\\sat-test-group-1\\ai_sat-test-group-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\h4jxrgtyqpz08xpk1v9g5bkk10\\workspace\\projects\\sat4\\ai_sat4.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\gyy7ar53z92hcb4bkpxrzafk10\\workspace\\projects\\project_name_861730\\ai_project_name_861730.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\gwy6501f4zafgcgzyf7cqgfk10\\workspace\\projects\\project_name_138709\\ai_project_name_138709.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\gtkxs6rftgbxa792whban8ak10\\workspace\\projects\\project_name_837695\\ai_project_name_837695.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\gm6428r7razq06cnfsevqdfk10\\workspace\\projects\\project_name_210917\\ai_project_name_210917.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\gm6428r7razq06cnfsevqdfk10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\gfvgy9y96cbkmkdh7xpdws9k10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\gefatbagp2k36eypa009ns9k10\\workspace\\projects\\project_name_141159\\ai_project_name_141159.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\gdmmdqw8rwx4h8tdhzknawqk10\\workspace\\projects\\project_name_131962_shared\\ai_project_name_131962_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\g35q5ekms15zsv2jp9vsd3hk10\\workspace\\projects\\project_name_742271\\ai_project_name_742271.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fw0crqw1hctfbf6c6bg1cwqk10\\workspace\\projects\\project_name_268024_shared\\ai_project_name_268024_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\bug-em-shared\\ai_bug-em-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\clone_14_hd_6June_2026\\ai_clone_14_hd_6June_2026.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\datalog2_31_project\\ai_datalog2_31_project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\prj1_hd_6june2026\\ai_prj1_hd_6june2026.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\prjAndModel\\ai_prjAndModel.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\prjModelAndDataset\\ai_prjModelAndDataset.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\prjOnly\\ai_prjOnly.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\shared-test-prj\\ai_shared-test-prj.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\test21_clone\\ai_test21_clone.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fv7er6m9prcy7emqeb531xwj10\\workspace\\projects\\TestPrj\\ai_TestPrj.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\frb5azc94k4cs4zbk7eh2gfk10\\workspace\\projects\\Dataset_Project_66524\\ai_Dataset_Project_66524.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fpb93h6t63ek7xvb2dt78hck10\\workspace\\projects\\project_name_385300\\ai_project_name_385300.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fmwkms3kyzcfgksa2sw94xfk10\\workspace\\projects\\project_name_272488_shared\\ai_project_name_272488_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fhkrff5p6gwjkgsptdw9t8ak10\\workspace\\projects\\project_name_318678\\ai_project_name_318678.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fhgbzmqzgjee61vb9xtd89ak10\\workspace\\projects\\project_name_120446\\ai_project_name_120446.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ffb6e520-1471-46b6-836e-22939f09ca40\\workspace\\projects\\Project_name_242394\\ai_Project_name_242394.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ffb6e520-1471-46b6-836e-22939f09ca40\\workspace\\projects\\Project_name_426469\\ai_Project_name_426469.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ffb6e520-1471-46b6-836e-22939f09ca40\\workspace\\projects\\Project_name_473059\\ai_Project_name_473059.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ffb6e520-1471-46b6-836e-22939f09ca40\\workspace\\projects\\Project_name_938069\\ai_Project_name_938069.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fe9a68d6-4c99-4179-829f-39034b4d2c92\\workspace\\projects\\Project_name_322462\\ai_Project_name_322462.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fe9a68d6-4c99-4179-829f-39034b4d2c92\\workspace\\projects\\Project_name_459818\\ai_Project_name_459818.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fe9a68d6-4c99-4179-829f-39034b4d2c92\\workspace\\projects\\Project_name_767999\\ai_Project_name_767999.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fe9a68d6-4c99-4179-829f-39034b4d2c92\\workspace\\projects\\Project_name_97899\\ai_Project_name_97899.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fe6538ed-db0a-49f7-84b4-f15c4e3f60ed\\workspace\\projects\\Project_name_536296\\ai_Project_name_536296.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fe6538ed-db0a-49f7-84b4-f15c4e3f60ed\\workspace\\projects\\Project_name_890119\\ai_Project_name_890119.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fd333ee3-8195-4386-9bca-2ac54703c5f9\\workspace\\projects\\SegmentationTest\\ai_SegmentationTest.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fd2j6gm7zver2hxkwyevyffk10\\workspace\\projects\\project_name_725399-shared\\ai_project_name_725399-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fcqm9r0kn2vgqx05019nqgfk10\\workspace\\projects\\project_name_457692_shared\\ai_project_name_457692_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fcdef292-c680-47cc-8cd9-c6c3f87d0340\\workspace\\projects\\Project_name_206604\\ai_Project_name_206604.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fcbv4m5f3ebmsppx8qhkqgfk10\\workspace\\projects\\project_name_396501_shared\\ai_project_name_396501_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fbbaaa02-4ca9-4c70-90c4-8260cb82c9ce\\workspace\\projects\\Project_name_17884\\ai_Project_name_17884.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb632ef6-a925-499f-970d-282819079f70\\workspace\\projects\\Project_name_132372\\ai_Project_name_132372.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb4010f3-0748-433d-ba35-0d457687b070\\workspace\\projects\\Project_name_967018\\ai_Project_name_967018.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb15813e-9727-4a79-8ddb-8010c6634671\\workspace\\projects\\Project_name_108379\\ai_Project_name_108379.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb15813e-9727-4a79-8ddb-8010c6634671\\workspace\\projects\\Project_name_634086\\ai_Project_name_634086.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb15813e-9727-4a79-8ddb-8010c6634671\\workspace\\projects\\Project_name_704962\\ai_Project_name_704962.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb15813e-9727-4a79-8ddb-8010c6634671\\workspace\\projects\\Project_name_949361\\ai_Project_name_949361.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb007629-0ddf-4351-b521-174058e6cdde\\workspace\\projects\\Project_name_369375\\ai_Project_name_369375.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb007629-0ddf-4351-b521-174058e6cdde\\workspace\\projects\\Project_name_437449\\ai_Project_name_437449.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb007629-0ddf-4351-b521-174058e6cdde\\workspace\\projects\\Project_name_622101\\ai_Project_name_622101.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb007629-0ddf-4351-b521-174058e6cdde\\workspace\\projects\\Project_name_959294\\ai_Project_name_959294.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fb007629-0ddf-4351-b521-174058e6cdde\\workspace\\projects\\Project_name_972421\\ai_Project_name_972421.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\fan51cf8dzm81q90ysnb4xfk10\\workspace\\projects\\project_name_364406_shared\\ai_project_name_364406_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f9853d02-f461-4f19-a685-a2a398b4dec4\\workspace\\projects\\Project_name_131532\\ai_Project_name_131532.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f9853d02-f461-4f19-a685-a2a398b4dec4\\workspace\\projects\\Project_name_255038\\ai_Project_name_255038.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f9853d02-f461-4f19-a685-a2a398b4dec4\\workspace\\projects\\Project_name_374971\\ai_Project_name_374971.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f9853d02-f461-4f19-a685-a2a398b4dec4\\workspace\\projects\\Project_name_624988\\ai_Project_name_624988.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f9853d02-f461-4f19-a685-a2a398b4dec4\\workspace\\projects\\Project_name_907644\\ai_Project_name_907644.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f961c877-f3f7-4294-8db6-3fbdecabecdb\\workspace\\projects\\Project_name_596292\\ai_Project_name_596292.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f961c877-f3f7-4294-8db6-3fbdecabecdb\\workspace\\projects\\Project_name_72653\\ai_Project_name_72653.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f8a13d17-ff86-4b12-a725-4fd92b0ad4e1\\workspace\\projects\\Project_name_442369\\ai_Project_name_442369.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f8a13d17-ff86-4b12-a725-4fd92b0ad4e1\\workspace\\projects\\Project_name_673825\\ai_Project_name_673825.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f8a13d17-ff86-4b12-a725-4fd92b0ad4e1\\workspace\\projects\\Project_name_841169\\ai_Project_name_841169.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f8a13d17-ff86-4b12-a725-4fd92b0ad4e1\\workspace\\projects\\Project_name_975001\\ai_Project_name_975001.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f881e94b-7fee-4a9d-9154-f201daac3113\\workspace\\projects\\Project_name_575152\\ai_Project_name_575152.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f881e94b-7fee-4a9d-9154-f201daac3113\\workspace\\projects\\Project_name_602882\\ai_Project_name_602882.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f881e94b-7fee-4a9d-9154-f201daac3113\\workspace\\projects\\Project_name_713175\\ai_Project_name_713175.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f881e94b-7fee-4a9d-9154-f201daac3113\\workspace\\projects\\Project_name_924727\\ai_Project_name_924727.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f881e94b-7fee-4a9d-9154-f201daac3113\\workspace\\projects\\Project_name_990069\\ai_Project_name_990069.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f87be57a-961f-431f-b005-2bf47c0517b5\\workspace\\projects\\Project_name_534306\\ai_Project_name_534306.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f87055b2-b0f8-456a-9548-90a075f8bea7\\workspace\\projects\\Project_name_853049\\ai_Project_name_853049.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f87055b2-b0f8-456a-9548-90a075f8bea7\\workspace\\projects\\Project_name_876103\\ai_Project_name_876103.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f87055b2-b0f8-456a-9548-90a075f8bea7\\workspace\\projects\\Project_name_885718\\ai_Project_name_885718.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f7d5842c-5312-4485-8b83-8c84cc0d2761\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f76e25b6-490c-42d6-85ba-51cba736d42a\\workspace\\projects\\Project_name_528934\\ai_Project_name_528934.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f76e25b6-490c-42d6-85ba-51cba736d42a\\workspace\\projects\\Project_name_860776\\ai_Project_name_860776.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f765d967-576b-4f0a-b79d-0976cf42584c\\workspace\\projects\\Project_name_174428\\ai_Project_name_174428.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f765d967-576b-4f0a-b79d-0976cf42584c\\workspace\\projects\\Project_name_319866\\ai_Project_name_319866.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f765d967-576b-4f0a-b79d-0976cf42584c\\workspace\\projects\\Project_name_440145\\ai_Project_name_440145.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f765d967-576b-4f0a-b79d-0976cf42584c\\workspace\\projects\\Project_name_532919\\ai_Project_name_532919.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f765d967-576b-4f0a-b79d-0976cf42584c\\workspace\\projects\\Project_name_585417\\ai_Project_name_585417.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f718fb0b-666a-4841-afd3-33dc9ea504ed\\workspace\\projects\\p\\ai_p.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f718fb0b-666a-4841-afd3-33dc9ea504ed\\workspace\\projects\\sat\\ai_sat.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f6f7f579-7840-4e3a-a0f5-d4719565664e\\workspace\\projects\\Project_name_298208\\ai_Project_name_298208.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f6f7f579-7840-4e3a-a0f5-d4719565664e\\workspace\\projects\\Project_name_388660\\ai_Project_name_388660.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f6f7f579-7840-4e3a-a0f5-d4719565664e\\workspace\\projects\\Project_name_972997\\ai_Project_name_972997.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f6be2f44-7b85-46f0-b5ff-8336c888aa85\\workspace\\projects\\Project_name_245124\\ai_Project_name_245124.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f6be2f44-7b85-46f0-b5ff-8336c888aa85\\workspace\\projects\\Project_name_494545\\ai_Project_name_494545.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5ce4384-8e1d-4cdc-b186-825f19d824ec\\workspace\\projects\\Project_name_544253\\ai_Project_name_544253.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\get_started_asset_tracking_mlc\\ai_get_started_asset_tracking_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\get_started_har_monitor_mlc\\ai_get_started_har_monitor_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\get_started_hvac_monitor_mlc\\ai_get_started_hvac_monitor_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\test '
#  'ispu\\ai_test ispu.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\test '
#  'project\\ai_test project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\projects\\fancoil\\ai_fancoil.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\projects\\my_asset_tracking\\ai_my_asset_tracking.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\projects\\my_asset_tracking_clone_test\\ai_my_asset_tracking_clone_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\projects\\my_at_for_iot_ble_testing\\ai_my_at_for_iot_ble_testing.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\projects\\sat_nucleo\\ai_sat_nucleo.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\projects\\test_1\\ai_test_1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\projects\\test_2\\ai_test_2.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f5c5a7a8-44fb-4b16-bcef-df8dc08fae8f\\workspace\\projects\\test_clone\\ai_test_clone.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f52bc342-4a7d-4b82-b9c2-91479ac32d11\\workspace\\prova\\ai_prova.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f37e8f51-54a9-4e16-bd4a-1073419d04ac\\workspace\\projects\\Project_name_101769\\ai_Project_name_101769.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f37e8f51-54a9-4e16-bd4a-1073419d04ac\\workspace\\projects\\Project_name_519824\\ai_Project_name_519824.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f37e8f51-54a9-4e16-bd4a-1073419d04ac\\workspace\\projects\\Project_name_799248\\ai_Project_name_799248.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f37e8f51-54a9-4e16-bd4a-1073419d04ac\\workspace\\projects\\Project_name_890078\\ai_Project_name_890078.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f326297b-c598-45c6-af23-4b1e618b20eb\\workspace\\projects\\Project_name_102247\\ai_Project_name_102247.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f326297b-c598-45c6-af23-4b1e618b20eb\\workspace\\projects\\Project_name_405999\\ai_Project_name_405999.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f326297b-c598-45c6-af23-4b1e618b20eb\\workspace\\projects\\Project_name_631952\\ai_Project_name_631952.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f326297b-c598-45c6-af23-4b1e618b20eb\\workspace\\projects\\Project_name_765132\\ai_Project_name_765132.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f326297b-c598-45c6-af23-4b1e618b20eb\\workspace\\projects\\Project_name_817697\\ai_Project_name_817697.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f2vx8p5ghfdaydwjxmee5gfk10\\workspace\\projects\\project_name_882667-shared\\ai_project_name_882667-shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f2ef69cc-2447-41d2-b957-53fcc22ce08d\\workspace\\projects\\Project_name_244741\\ai_Project_name_244741.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f20dcf45-1699-41a2-a94d-0b63aa059bec\\workspace\\projects\\Project_name_797131\\ai_Project_name_797131.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\f20ac81c-a3ff-4d1a-9ba3-e391f22fa6e1\\workspace\\projects\\Project_name_190128\\ai_Project_name_190128.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\etfmgc2j1vbyar52nvwvayqk10\\workspace\\projects\\project_name_770042_shared\\ai_project_name_770042_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eqkj065t0x51qdbz2ahzwffk10\\workspace\\projects\\project_name_663466\\ai_project_name_663466.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\egsbag8y2gsxr1ktt5y6nt5k10\\workspace\\projects\\test-project-833\\ai_test-project-833.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\egsbag8y2gsxr1ktt5y6nt5k10\\workspace\\projects\\test-project-834\\ai_test-project-834.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\efae6304-2a1d-4d9c-8c85-41f11b787895\\workspace\\projects\\Project_name_382716\\ai_Project_name_382716.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\efae6304-2a1d-4d9c-8c85-41f11b787895\\workspace\\projects\\Project_name_998465\\ai_Project_name_998465.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ef13b057-941f-4fe0-a374-e940cfd41f55\\workspace\\projects\\asd\\ai_asd.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ef13b057-941f-4fe0-a374-e940cfd41f55\\workspace\\projects\\Giovanni-test\\ai_Giovanni-test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ef13b057-941f-4fe0-a374-e940cfd41f55\\workspace\\projects\\Project1\\ai_Project1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ef13b057-941f-4fe0-a374-e940cfd41f55\\workspace\\projects\\Prova_2\\ai_Prova_2.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ef13b057-941f-4fe0-a374-e940cfd41f55\\workspace\\projects\\TestForVespucci\\ai_TestForVespucci.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\1\\ai_1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_101940\\ai_new_project_name_101940.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_152431\\ai_new_project_name_152431.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_194788\\ai_new_project_name_194788.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_283740\\ai_new_project_name_283740.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_364646\\ai_new_project_name_364646.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_368651\\ai_new_project_name_368651.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_471867\\ai_new_project_name_471867.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_498899\\ai_new_project_name_498899.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_513954\\ai_new_project_name_513954.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_677242\\ai_new_project_name_677242.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_740873\\ai_new_project_name_740873.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_755993\\ai_new_project_name_755993.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_832936\\ai_new_project_name_832936.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_866336\\ai_new_project_name_866336.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_878488\\ai_new_project_name_878488.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_922012\\ai_new_project_name_922012.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eec06b88-d833-4f9e-a4e2-2b8b86785e35\\workspace\\projects\\new_project_name_946867\\ai_new_project_name_946867.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eeb24300-66d0-49f3-8ba2-66505daa09b0\\workspace\\projects\\PrivateProject2\\ai_PrivateProject2.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eeb24300-66d0-49f3-8ba2-66505daa09b0\\workspace\\projects\\PrivateTest\\ai_PrivateTest.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eeb24300-66d0-49f3-8ba2-66505daa09b0\\workspace\\projects\\Test\\ai_Test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\eeb24300-66d0-49f3-8ba2-66505daa09b0\\workspace\\projects\\Test2\\ai_Test2.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ee6b4ea7-fee9-4aef-bf1b-7413adb41006\\workspace\\projects\\Project_name_392568\\ai_Project_name_392568.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ed1f73ec-73e0-4bb8-becc-c70862b6fd9f\\workspace\\projects\\Project_name_243010\\ai_Project_name_243010.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ed1f73ec-73e0-4bb8-becc-c70862b6fd9f\\workspace\\projects\\Project_name_42370\\ai_Project_name_42370.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ed1f73ec-73e0-4bb8-becc-c70862b6fd9f\\workspace\\projects\\Project_name_462872\\ai_Project_name_462872.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ed1f73ec-73e0-4bb8-becc-c70862b6fd9f\\workspace\\projects\\Project_name_466943\\ai_Project_name_466943.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ed1f73ec-73e0-4bb8-becc-c70862b6fd9f\\workspace\\projects\\Project_name_684173\\ai_Project_name_684173.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ece9cbca-5ab0-4be2-af3f-afe01e569e20\\workspace\\projects\\Project_name_285696\\ai_Project_name_285696.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ebd4fbpwxaw45y5d3zhrfksj10\\workspace\\projects\\test\\ai_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea9b629b-bcab-4d80-b540-b961ae227cae\\workspace\\projects\\20240705_automode_ux_test\\ai_20240705_automode_ux_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\20240402_drilling_machine\\ai_20240402_drilling_machine.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\20240404_drilling_machine\\ai_20240404_drilling_machine.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\240823_atr_lecce\\ai_240823_atr_lecce.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\20240705_automode_ux_test\\ai_20240705_automode_ux_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\20251029-iot-test\\ai_20251029-iot-test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\20260326_LINKS\\ai_20260326_LINKS.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\ble-test-ux\\ai_ble-test-ux.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\bletestsat\\ai_bletestsat.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\bug\\ai_bug.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\iot-system-test\\ai_iot-system-test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\mlc_odr\\ai_mlc_odr.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\my-joystick\\ai_my-joystick.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\my-sat-project\\ai_my-sat-project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\my-usecase-project\\ai_my-usecase-project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\my-usecase-project-1\\ai_my-usecase-project-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\old-project\\ai_old-project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\project-1\\ai_project-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\sat-iot-system-1\\ai_sat-iot-system-1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\tennis_activity\\ai_tennis_activity.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\test-wrong-names\\ai_test-wrong-names.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\test_for_sharing_bug\\ai_test_for_sharing_bug.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\ea66524a-2778-4966-a6ed-340abc5bc04b\\workspace\\projects\\VladimirJANOUSEK\\ai_VladimirJANOUSEK.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e9bffe6a-9966-4c48-8b41-a64577359f45\\workspace\\projects\\20240705_automode_ux_test\\ai_20240705_automode_ux_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e928a5da-1ff0-40ef-b001-f24c4a6beec4\\workspace\\projects\\Project_name_47890\\ai_Project_name_47890.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e928a5da-1ff0-40ef-b001-f24c4a6beec4\\workspace\\projects\\Project_name_798329\\ai_Project_name_798329.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e928a5da-1ff0-40ef-b001-f24c4a6beec4\\workspace\\projects\\Project_name_971747\\ai_Project_name_971747.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e8ce0cb9-042d-4982-9a07-fa2e3c7524a4\\workspace\\projects\\Project_name_500129\\ai_Project_name_500129.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e8ce0cb9-042d-4982-9a07-fa2e3c7524a4\\workspace\\projects\\Project_name_50162\\ai_Project_name_50162.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e8ce0cb9-042d-4982-9a07-fa2e3c7524a4\\workspace\\projects\\Project_name_576024\\ai_Project_name_576024.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e8ce0cb9-042d-4982-9a07-fa2e3c7524a4\\workspace\\projects\\Project_name_86457\\ai_Project_name_86457.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e897b470-2c3a-4e70-92d9-680bd4e7db9b\\workspace\\projects\\Project_name_236681\\ai_Project_name_236681.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e897b470-2c3a-4e70-92d9-680bd4e7db9b\\workspace\\projects\\Project_name_836629\\ai_Project_name_836629.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e891f69d-c884-4a03-a0f5-0cb9a36483ae\\workspace\\projects\\Project_name_111287\\ai_Project_name_111287.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e891f69d-c884-4a03-a0f5-0cb9a36483ae\\workspace\\projects\\Project_name_370213\\ai_Project_name_370213.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e891f69d-c884-4a03-a0f5-0cb9a36483ae\\workspace\\projects\\Project_name_607192\\ai_Project_name_607192.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e891f69d-c884-4a03-a0f5-0cb9a36483ae\\workspace\\projects\\Project_name_72137\\ai_Project_name_72137.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e891f69d-c884-4a03-a0f5-0cb9a36483ae\\workspace\\projects\\Project_name_870694\\ai_Project_name_870694.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e84c512c-120e-47cc-84e9-33eb697ec7a0\\workspace\\projects\\Project_name_250089\\ai_Project_name_250089.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e84c512c-120e-47cc-84e9-33eb697ec7a0\\workspace\\projects\\Project_name_327213\\ai_Project_name_327213.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\e84c512c-120e-47cc-84e9-33eb697ec7a0\\workspace\\projects\\Project_name_820003\\ai_Project_name_820003.json',
# ...
#  'proj-api-volume-dump\\proj-api-volume-dump\\190d94d2-cd39-4929-92f7-da62939ac036\\workspace\\get_started_hvac_monitor_mlc\\ai_get_started_hvac_monitor_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\190d94d2-cd39-4929-92f7-da62939ac036\\workspace\\get_started_image_classification\\ai_get_started_image_classification.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\190d94d2-cd39-4929-92f7-da62939ac036\\workspace\\get_started_ispu_ai_fan_monitor\\ai_get_started_ispu_ai_fan_monitor.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\190d94d2-cd39-4929-92f7-da62939ac036\\workspace\\get_started_mlc\\ai_get_started_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\190d94d2-cd39-4929-92f7-da62939ac036\\workspace\\get_started_vibration_classification\\ai_get_started_vibration_classification.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\190d94d2-cd39-4929-92f7-da62939ac036\\workspace\\hvac_monitor\\ai_hvac_monitor.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\185f143d-7ec4-45a8-9c17-9feba4498c86\\workspace\\projects\\Project_name_420832\\ai_Project_name_420832.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\185f143d-7ec4-45a8-9c17-9feba4498c86\\workspace\\projects\\Project_name_615950\\ai_Project_name_615950.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\185f143d-7ec4-45a8-9c17-9feba4498c86\\workspace\\projects\\Project_name_849164\\ai_Project_name_849164.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\185f143d-7ec4-45a8-9c17-9feba4498c86\\workspace\\projects\\Project_name_893065\\ai_Project_name_893065.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\185f143d-7ec4-45a8-9c17-9feba4498c86\\workspace\\projects\\Project_name_89841\\ai_Project_name_89841.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\16f50b96-ce7b-46fc-beed-5ce5b11bb442\\workspace\\projects\\cloned-sat\\ai_cloned-sat.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\16f50b96-ce7b-46fc-beed-5ce5b11bb442\\workspace\\projects\\joystick-project\\ai_joystick-project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\16eaf407-dd00-4bd7-8a32-73cca29b3ced\\workspace\\projects\\Project_name_788202\\ai_Project_name_788202.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\16986b79-a957-4306-9530-14b304becb94\\workspace\\projects\\Project_name_355966\\ai_Project_name_355966.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\16986b79-a957-4306-9530-14b304becb94\\workspace\\projects\\Project_name_358059\\ai_Project_name_358059.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\16986b79-a957-4306-9530-14b304becb94\\workspace\\projects\\Project_name_37016\\ai_Project_name_37016.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\16986b79-a957-4306-9530-14b304becb94\\workspace\\projects\\Project_name_45012\\ai_Project_name_45012.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\16986b79-a957-4306-9530-14b304becb94\\workspace\\projects\\Project_name_45379\\ai_Project_name_45379.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\1680453a-66c8-421d-8295-069efd50f845\\workspace\\projects\\Project_name_239514\\ai_Project_name_239514.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\1680453a-66c8-421d-8295-069efd50f845\\workspace\\projects\\Project_name_329087\\ai_Project_name_329087.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\1680453a-66c8-421d-8295-069efd50f845\\workspace\\projects\\Project_name_453738\\ai_Project_name_453738.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\1680453a-66c8-421d-8295-069efd50f845\\workspace\\projects\\Project_name_493784\\ai_Project_name_493784.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\1680453a-66c8-421d-8295-069efd50f845\\workspace\\projects\\Project_name_603358\\ai_Project_name_603358.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\15e564d4-3a4e-4b58-89fe-22c71ac47f6d\\workspace\\projects\\Project_name_633037\\ai_Project_name_633037.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\13nv310mhkzry93cvfe5kbrk10\\workspace\\projects\\project_name_829546_shared\\ai_project_name_829546_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\137ded34-865f-4a8e-9a56-64dca48bf8b4\\workspace\\projects\\Project_name_162360\\ai_Project_name_162360.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\137ded34-865f-4a8e-9a56-64dca48bf8b4\\workspace\\projects\\Project_name_201349\\ai_Project_name_201349.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\137ded34-865f-4a8e-9a56-64dca48bf8b4\\workspace\\projects\\Project_name_398143\\ai_Project_name_398143.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\137ded34-865f-4a8e-9a56-64dca48bf8b4\\workspace\\projects\\Project_name_885051\\ai_Project_name_885051.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\13633f27-fd29-40e8-9708-ba8af813ede3\\workspace\\projects\\Project_name_146003\\ai_Project_name_146003.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\13633f27-fd29-40e8-9708-ba8af813ede3\\workspace\\projects\\Project_name_400447\\ai_Project_name_400447.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\13633f27-fd29-40e8-9708-ba8af813ede3\\workspace\\projects\\Project_name_83669\\ai_Project_name_83669.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\13633f27-fd29-40e8-9708-ba8af813ede3\\workspace\\projects\\Project_name_912360\\ai_Project_name_912360.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\132jtzp52mfsfm5x38w3cwqk10\\workspace\\projects\\project_name_949077_shared\\ai_project_name_949077_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\12652424-50d1-7062-3dc1-b15a80dd0e33\\workspace\\projects\\assettracking\\ai_assettracking.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11bb2c77-b578-41a8-9355-1ddb334213f0\\workspace\\projects\\Project_name_214114\\ai_Project_name_214114.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11bb2c77-b578-41a8-9355-1ddb334213f0\\workspace\\projects\\Project_name_227003\\ai_Project_name_227003.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11bb2c77-b578-41a8-9355-1ddb334213f0\\workspace\\projects\\Project_name_409061\\ai_Project_name_409061.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11bb2c77-b578-41a8-9355-1ddb334213f0\\workspace\\projects\\Project_name_439720\\ai_Project_name_439720.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11bb2c77-b578-41a8-9355-1ddb334213f0\\workspace\\projects\\Project_name_513408\\ai_Project_name_513408.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11616561-aba2-45d1-bc1b-8d5e98bcc842\\workspace\\projects\\Project_name_443841\\ai_Project_name_443841.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11616561-aba2-45d1-bc1b-8d5e98bcc842\\workspace\\projects\\Project_name_635317\\ai_Project_name_635317.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11616561-aba2-45d1-bc1b-8d5e98bcc842\\workspace\\projects\\Project_name_707508\\ai_Project_name_707508.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11616561-aba2-45d1-bc1b-8d5e98bcc842\\workspace\\projects\\Project_name_811562\\ai_Project_name_811562.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\11616561-aba2-45d1-bc1b-8d5e98bcc842\\workspace\\projects\\Project_name_984017\\ai_Project_name_984017.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\113fe401-3224-49c0-97f3-485abcfc0759\\workspace\\projects\\Project_name_84399\\ai_Project_name_84399.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\108d0ab4-e4a7-4ab3-bba3-13d0d86a86bd\\workspace\\projects\\20240705_automode_ux_test\\ai_20240705_automode_ux_test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0wrrg1yg682egrd5dx6xdyqk10\\workspace\\projects\\project_name_168026_shared\\ai_project_name_168026_shared.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0m0e7zr9gevks0r9t6c0sdfk10\\workspace\\projects\\project_name_345730\\ai_project_name_345730.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0f6fb13c-300d-4247-a739-8836fe081c86\\workspace\\projects\\Project_name_422032\\ai_Project_name_422032.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0f06acfe-5650-4827-af24-94589e4dc201\\workspace\\projects\\Project_name_909748\\ai_Project_name_909748.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0e78a167-8331-4622-9410-1be0d8c2f79a\\workspace\\projects\\Project_name_294620\\ai_Project_name_294620.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0e68a6cc-126a-402b-bfd6-0536f26eb145\\workspace\\projects\\Project_name_40048\\ai_Project_name_40048.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0e68a6cc-126a-402b-bfd6-0536f26eb145\\workspace\\projects\\Project_name_462986\\ai_Project_name_462986.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0e68a6cc-126a-402b-bfd6-0536f26eb145\\workspace\\projects\\Project_name_540884\\ai_Project_name_540884.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0e68a6cc-126a-402b-bfd6-0536f26eb145\\workspace\\projects\\Project_name_631353\\ai_Project_name_631353.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0e68a6cc-126a-402b-bfd6-0536f26eb145\\workspace\\projects\\Project_name_803357\\ai_Project_name_803357.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0e2b478e-515c-42bd-a99a-7b9f14e24dae\\workspace\\projects\\Project_name_264966\\ai_Project_name_264966.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0d7520bc-c240-4abe-8126-331251333e6f\\workspace\\projects\\Project_name_376210\\ai_Project_name_376210.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0d7520bc-c240-4abe-8126-331251333e6f\\workspace\\projects\\Project_name_376403\\ai_Project_name_376403.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0d7520bc-c240-4abe-8126-331251333e6f\\workspace\\projects\\Project_name_608834\\ai_Project_name_608834.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0d7520bc-c240-4abe-8126-331251333e6f\\workspace\\projects\\Project_name_766530\\ai_Project_name_766530.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0d7520bc-c240-4abe-8126-331251333e6f\\workspace\\projects\\Project_name_834012\\ai_Project_name_834012.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0c4705ba-33fe-441a-8e34-2de834548fd6\\workspace\\projects\\Project_name_382729\\ai_Project_name_382729.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0c4705ba-33fe-441a-8e34-2de834548fd6\\workspace\\projects\\Project_name_517802\\ai_Project_name_517802.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0c46f6a9-d2ec-47c3-9a90-7175d095cbd9\\workspace\\projects\\Project_name_914557\\ai_Project_name_914557.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\09b64331-eada-413a-a98b-aa7edb9b65a8\\workspace\\get_started_image_classification_mcu\\ai_get_started_image_classification_mcu.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\09b64331-eada-413a-a98b-aa7edb9b65a8\\workspace\\Test\\ai_Test.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\065542shw19gxt44axvw15zj10\\workspace\\projects\\clone1\\ai_clone1.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0571882e-dc40-4635-89e2-0514548402c0\\workspace\\projects\\Project_name_357904\\ai_Project_name_357904.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0571882e-dc40-4635-89e2-0514548402c0\\workspace\\projects\\Project_name_592405\\ai_Project_name_592405.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\0571882e-dc40-4635-89e2-0514548402c0\\workspace\\projects\\Project_name_626522\\ai_Project_name_626522.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\05534a6a-b0fa-462d-8d34-00aaf8dff9bf\\workspace\\projects\\Project_name_328244\\ai_Project_name_328244.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\05534a6a-b0fa-462d-8d34-00aaf8dff9bf\\workspace\\projects\\Project_name_722277\\ai_Project_name_722277.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\053b422c-b512-4cda-b3c8-fa125dcf4a50\\workspace\\get_started_asset_tracking_mlc\\ai_get_started_asset_tracking_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\053b422c-b512-4cda-b3c8-fa125dcf4a50\\workspace\\projects\\Asset_Tracking\\ai_Asset_Tracking.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\053b422c-b512-4cda-b3c8-fa125dcf4a50\\workspace\\projects\\cloned_project\\ai_cloned_project.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\04a3d7b0-4d2d-49d2-b9ea-efb75381641f\\workspace\\projects\\Project_name_511641\\ai_Project_name_511641.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\04020797-55be-4846-a162-3e0450d780b6\\workspace\\projects\\Project_name_564664\\ai_Project_name_564664.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\03ca20d4-934c-43bf-8d3d-c36b51625861\\workspace\\projects\\Project_name_151104\\ai_Project_name_151104.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\037b7f7a-40a9-4b41-8e6e-5ca7d952b037\\workspace\\projects\\Project_name_502393\\ai_Project_name_502393.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\017e85d9-d1ba-4086-a4c8-946820dd33a2\\workspace\\projects\\Project_name_310655\\ai_Project_name_310655.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\011ce894-872b-4a1d-8fee-fb3de92d88c2\\workspace\\projects\\Project_name_185734\\ai_Project_name_185734.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\00da9f2f-2047-48a5-b474-144d145476b3\\workspace\\projects\\Project_name_234062\\ai_Project_name_234062.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\00da9f2f-2047-48a5-b474-144d145476b3\\workspace\\projects\\Project_name_254658\\ai_Project_name_254658.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\00da9f2f-2047-48a5-b474-144d145476b3\\workspace\\projects\\Project_name_678932\\ai_Project_name_678932.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\00da9f2f-2047-48a5-b474-144d145476b3\\workspace\\projects\\Project_name_792345\\ai_Project_name_792345.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\00000000-0000-0000-0000-000000000000\\workspace\\projects\\project_name_20508\\ai_project_name_20508.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_drilling_machine_mlc\\ai_get_started_drilling_machine_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_fan_coil_monitoring_mlc\\ai_get_started_fan_coil_monitoring_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_gesture_recognition_mlc\\ai_get_started_gesture_recognition_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_head_gestures_mlc\\ai_get_started_head_gestures_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_human_activity_recognition_mlc\\ai_get_started_human_activity_recognition_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_joystick_monitoring_mlc\\ai_get_started_joystick_monitoring_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_smart_asset_tracking_mlc\\ai_get_started_smart_asset_tracking_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_tennis_activity_mlc\\ai_get_started_tennis_activity_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_terrain_classification_mlc\\ai_get_started_terrain_classification_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\get-started-projects\\get_started_vibration_monitoring_mlc\\ai_get_started_vibration_monitoring_mlc.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\.assets\\schemas\\ai_deployments_schema.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\.assets\\schemas\\ai_main_schema.json',
#  'proj-api-volume-dump\\proj-api-volume-dump\\.assets\\artifacts\\.assets\\schemas\\ai_models_schema.json']

# %% [markdown]
# ## Convert JSON files in to CSV for use by *OpenRefine* tool

# %%
import csv
import json
import os
import re
from pathlib import Path


def flatten_json_to_paths(data, prefix=""):
    """Recursively flattens a JSON structure into a dictionary of dot-notated

    paths.
    E.g., {"models": [{"training": {"runtime": "python"}}]} becomes
    {"models.0.training.runtime": "python"}
    """
    flat_dict = {}

    if isinstance(data, dict):
        for key, value in data.items():
            new_prefix = f"{prefix}.{key}" if prefix else key
            flat_dict.update(flatten_json_to_paths(value, new_prefix))
    elif isinstance(data, list):
        for index, item in enumerate(data):
            new_prefix = f"{prefix}.{index}"
            flat_dict.update(flatten_json_to_paths(item, new_prefix))
    else:
        # Standardize empty or null values to text
        flat_dict[prefix] = str(data) if data is not None else ""

    return flat_dict


def clean_and_load(file_path):
    """Safely handles empty files, basic encoding fallbacks, and minor syntax

    repairs.
    """
    content = ""
    # Try reading with standard UTF-8 first
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            content = f.read().strip()
    except UnicodeDecodeError:
        # Fallback to latin-1 to avoid decoding errors for unexpected encodings
        try:
            with open(file_path, "r", encoding="latin-1") as f:
                content = f.read().strip()
            # If it's a raw binary artifact with a false extension, drop it
            if content and not any(
                content.startswith(c) for c in ["{", "[", '"', "\n", "\r", " "]
            ):
                return None
        except Exception:
            return None

    if not content:
        return None

    try:
        return json.loads(content)
    except json.JSONDecodeError:
        try:
            # Simple fallback to clean up trailing commas before closing braces/brackets
            cleaned = re.sub(r",\s*([\]}])", r"\1", content)
            return json.loads(cleaned)
        except Exception:
            return None


def convert_json_list_to_csv(json_paths_list, output_csv_path):
    """Takes a list of file paths, flattens their structural configurations,

    and exports them to a unified CSV grid.
    """
    all_flattened_files = []
    all_discovered_columns = set()

    print(f"Processing {len(json_paths_list)} files...")

    for path_str in json_paths_list:
        file_path = Path(path_str)
        if not file_path.exists():
            continue

        data = clean_and_load(file_path)
        if data is None:
            continue  # Skips unreadable, empty, or false binary artifacts

        # Flatten nested structure to single layer paths
        flat_data = flatten_json_to_paths(data)

        if flat_data:
            # Inject a tracking column for identification in your UI analysis tool
            flat_data["_source_file_path"] = str(file_path)
            all_flattened_files.append(flat_data)
            all_discovered_columns.update(flat_data.keys())

    if not all_flattened_files:
        print("No valid JSON data could be processed or extracted.")
        return

    # Ensure the identifier tracking column sits cleanly at the front of the CSV layout
    headers = ["_source_file_path"] + sorted(
        list(all_discovered_columns - {"_source_file_path"})
    )

    print(
        f"Writing structural matrix with {len(headers)} unique columns to: {output_csv_path}"
    )

    with open(output_csv_path, "w", newline="", encoding="utf-8") as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=headers)
        writer.writeheader()

        for flat_entry in all_flattened_files:
            # Missing fields in specific schema versions automatically populate as empty strings
            writer.writerow(flat_entry)

    print("CSV generation successfully completed.")

# %%
# --- Example Pipeline Integration ---
if __name__ == "__main__":
    # Assuming you have the function from earlier or a pre-populated list
    # e.g., my_files = get_matching_json_paths("./proj-api-volume-dump")

    # For testing, you can pass an explicit list:
    # example_input_paths = [
    #     'proj-api-volume-dump/7b261599-24c5-49fa-91f8-5c115a75974e/workspace/projects/Project_name_418987/ai_Project_name_418987.json',
    #     'proj-api-volume-dump/cbf09bd6-be92-4286-bfee-d848f4c07ac7/workspace/projects/Project_name_278105/ai_Project_name_278105.json',
    # ]

    # output_destination = "./flattened_schema_matrix.csv"
    # convert_json_list_to_csv(example_input_paths, output_destination)

    convert_json_list_to_csv(ai_json_files, "./flattened_schema_matrix.csv")
# Out:
# Processing 1886 files...
# Writing structural matrix with 1999 unique columns to: ./flattened_schema_matrix.csv
# CSV generation successfully completed.

# %% [markdown]
# ## Preprocessing step for genson
#
# Take the dump of json from dev cluster, and pre process it to a folder which can be ingested by future algorithms

# %%
def anonymize_and_map_json_files(json_paths_list, output_dir):
    """Reads a list of JSON file paths, copies and renames them to a flat index

    structure (ai_<index>.json), and generates a CSV file tracking the mapping
    between the original file path and the new indexed filename.

    :param json_paths_list: List of string paths pointing to your source JSON
    files.
    :param output_dir: Path or string specifying the target directory for
    outputs.
    """
    target_dir = Path(output_dir)
    target_dir.mkdir(parents=True, exist_ok=True)

    csv_mapping_path = target_dir / "name_mapping.csv"
    mapping_rows = []

    print(
        f"Beginning segregation and renaming for {len(json_paths_list)} files..."
    )

    for index, original_path_str in enumerate(json_paths_list):
        source_file = Path(original_path_str)

        # Ensure the file exists before processing
        if not source_file.exists():
            print(f"Warning: File not found, skipping: {original_path_str}")
            continue

        # Define the target uniform filename schema
        new_filename = f"ai_{index}.json"
        destination_file = target_dir / new_filename

        try:
            # Copy the file to the flat output directory
            shutil.copy2(source_file, destination_file)

            # Record the exact spatial mapping for your downstream data mining
            mapping_rows.append(
                {
                    "index": index,
                    "anonymous_filename": new_filename,
                    "original_path": str(source_file),
                }
            )

        except IOError as e:
            print(
                f"Failed to process or copy file {original_path_str} due to system error: {e}"
            )

    # Write the tracking index grid to name_mapping.csv
    csv_headers = ["index", "anonymous_filename", "original_path"]
    try:
        with open(
            csv_mapping_path, "w", newline="", encoding="utf-8"
        ) as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=csv_headers)
            writer.writeheader()
            writer.writerows(mapping_rows)

        print(
            f"Successfully processed files. Outputs and ledger mapped to: {target_dir}"
        )
    except IOError as e:
        print(f"Error writing the CSV mapping file: {e}")


# --- Quick Execution Check ---
if __name__ == "__main__":
    # Example input array derived from your search functions
    tracked_files = [
        "proj-api-volume-dump/c08a6da7-9afd-4c39-8ddf-12b85066ba8c/workspace/projects/ClonedAssetTracking/ai_get_started_asset_tracking_mlc_v10.json",
        "proj-api-volume-dump/ea66524a-2778-4966-a6ed-340abc5bc04b/workspace/projects/mlc_odr/ai_mlc_odr.json",
    ]

    # anonymize_and_map_json_files(
    #     tracked_files, "./processed_schema_workspace"
    # )

    anonymize_and_map_json_files(
        ai_json_files, "./processed_schema_workspace"
    )
# Out:
# Beginning segregation and renaming for 1886 files...
# Successfully processed files. Outputs and ledger mapped to: processed_schema_workspace
